# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/shl-dataset/dataset/sample_submission.csv
# /kaggle/input/shl-dataset/dataset/train.csv
# /kaggle/input/shl-dataset/dataset/test.csv
# /kaggle/input/shl-dataset/dataset/audios_test/audio_885.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_698.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1176.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1215.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_66.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_386.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1026.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_330.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_72.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_858.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_107.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_820.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_300.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_435.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_550.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_841.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_641.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_290.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_401.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_321.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_20.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_348.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_500.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_735.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_888.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_959.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_276.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1323.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1089.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1289.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_29.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_676.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_811.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_762.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1183.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1297.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_709.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_281.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_308.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1054.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_662.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_525.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_633.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_274.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_922.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_683.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1275.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_541.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_113.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_665.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_543.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1012.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_759.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_225.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_644.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1035.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1159.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1179.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1048.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_499.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1123.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1116.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_521.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1013.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_198.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1278.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_4.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_165.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_19.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_261.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_998.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_89.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1280.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_971.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_322.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1058.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1068.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_719.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1205.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1315.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1061.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1091.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_75.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_217.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_95.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_159.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_545.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_379.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_137.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1124.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_177.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_180.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_726.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1081.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_519.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_285.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_569.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_800.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_218.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_148.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_408.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1122.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_884.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_488.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_733.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_235.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_286.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_263.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1022.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_656.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1101.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1286.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_287.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1293.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_692.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1190.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1173.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_388.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_767.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1242.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1311.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_540.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_932.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_448.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_949.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_908.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_158.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_172.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_958.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_805.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_746.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_221.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_391.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_21.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1169.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_68.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_529.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_138.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1195.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_580.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_360.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1033.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1240.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_10.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_48.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1193.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1217.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1292.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_282.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_599.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_153.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_564.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1019.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_196.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1115.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_103.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1291.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_690.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_706.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1214.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1138.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_831.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_857.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1267.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_135.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_433.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_556.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_306.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_109.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1256.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_34.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_572.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_487.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_554.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_512.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1317.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_179.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_604.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_882.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_437.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_920.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_546.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1178.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_702.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1243.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_394.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_428.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1321.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_422.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_713.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_320.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_770.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_1166.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_151.wav
# /kaggle/input/shl-dataset/dataset/audios_test/audio_897.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_90.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_581.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_77.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_817.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_694.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1262.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_237.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_765.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1164.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1251.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1032.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_688.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_886.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1129.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_464.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1040.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_711.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_853.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_436.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_538.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_859.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_547.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1266.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_919.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1036.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_796.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_994.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_760.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_315.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1028.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_55.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1284.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_950.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_256.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_359.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_462.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_44.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_753.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_813.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_7.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1100.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1131.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_119.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_59.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_802.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_518.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_12.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_591.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_536.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1082.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_404.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_254.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_990.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_513.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_653.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1177.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_188.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_539.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_289.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_778.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1210.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_946.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_67.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_186.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_600.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1277.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_291.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_602.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1150.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1118.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1106.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1312.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_495.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_265.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_558.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_82.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_61.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_964.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_526.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1285.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_32.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_535.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_110.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1172.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_567.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1325.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_374.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_944.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_327.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_120.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_297.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1212.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_899.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_516.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_441.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_848.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1103.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_346.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_446.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_104.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1236.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_957.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_776.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1163.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_642.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_479.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_940.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1171.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_563.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_773.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_71.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_76.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_905.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_925.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_205.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_345.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_661.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_102.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1136.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1304.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_399.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1126.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1024.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_45.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_812.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_860.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_942.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_414.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_725.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1245.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_275.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_590.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_955.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_478.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_779.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_2.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_447.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_807.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_223.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1268.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_118.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1202.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_549.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1069.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_366.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_743.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_210.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_874.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_705.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_952.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_836.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_396.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1239.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_909.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_583.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1114.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_771.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_989.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1182.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_865.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_278.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_468.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_930.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_314.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_697.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_722.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_674.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1104.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1134.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1043.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_609.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1329.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1153.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_23.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_542.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_592.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_954.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_916.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_244.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_387.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_313.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1252.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_194.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_427.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_93.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1162.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_142.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_708.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_492.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_934.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_826.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_931.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_255.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_654.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_703.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_657.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_5.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_185.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1175.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1120.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1128.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1066.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_80.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_668.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_8.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_763.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_85.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1318.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_303.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_727.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1057.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_469.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_965.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_202.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_127.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_677.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_788.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_904.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_695.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_463.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1075.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_130.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_273.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_489.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_293.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1030.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_970.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_239.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_252.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_311.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_240.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_288.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1226.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_146.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_643.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_675.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_731.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1191.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_52.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_504.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1112.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_875.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_460.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1111.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_736.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1333.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_365.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_937.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_332.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1335.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_681.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_808.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_766.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_700.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1247.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_686.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1313.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_867.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_939.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_917.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_620.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1099.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_339.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1147.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_921.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_484.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_745.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1274.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1326.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_527.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_948.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_870.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_362.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_873.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_482.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1307.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_680.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_140.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1196.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_582.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_17.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_533.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_154.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_963.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_926.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1264.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1102.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_630.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_730.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_317.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_440.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_611.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_69.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_64.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_978.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_494.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_131.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_336.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_105.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_395.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_324.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_358.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_707.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_15.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_63.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_744.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1038.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_167.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_956.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_716.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_334.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_868.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_854.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_245.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_903.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_834.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1110.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_432.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_236.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1208.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_200.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1078.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1200.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_353.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_947.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_212.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_168.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_352.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_445.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_419.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1332.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_701.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_117.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1059.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_790.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_390.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_586.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_226.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_699.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_363.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_988.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_485.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_241.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_481.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_652.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_424.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_483.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1017.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_890.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1065.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_787.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_627.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1290.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_758.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1314.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_272.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_687.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_809.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_312.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_902.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1296.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_147.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_783.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_144.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_373.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_887.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_443.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_350.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_503.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_62.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_402.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1031.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_116.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_693.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_477.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_413.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1025.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_123.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_133.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_647.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1223.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_980.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_755.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_869.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1148.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_685.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_678.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_53.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1184.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_552.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1216.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1185.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_918.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_250.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_721.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_624.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_43.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_889.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_184.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_842.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1125.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_9.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_455.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1160.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_913.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_493.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_704.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_548.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1230.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_961.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_832.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_33.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_896.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_827.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_748.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_658.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_471.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1117.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_270.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_301.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_576.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_649.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1261.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_640.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_636.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1272.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1135.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_74.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_983.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_993.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_480.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1298.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_876.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_794.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_163.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_450.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_514.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_696.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_389.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1008.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_1187.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_724.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_490.wav
# /kaggle/input/shl-dataset/dataset/audios_train/audio_259.wav

# %%
# !pip install transformers torchaudio pandas numpy xgboost scikit-learn matplotlib
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.29.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchaudio) (2.5.1+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchaudio) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchaudio) (3.0.2)

# %%
import pandas as pd
import numpy as np
import torch
import torchaudio
from transformers import Wav2Vec2Processor, Wav2Vec2Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr
import xgboost as xgb
import matplotlib.pyplot as plt
import os

# %%
# !git clone https://huggingface.co/facebook/wav2vec2-base-960h
# Out:
# Cloning into 'wav2vec2-base-960h'...
# remote: Enumerating objects: 118, done.
# remote: Total 118 (delta 0), reused 0 (delta 0), pack-reused 118 (from 1)
# Receiving objects: 100% (118/118), 15.08 KiB | 7.54 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# Filtering content: 100% (3/3), 1.05 GiB | 135.09 MiB/s, done.

# %%
MODEL_PATH = "/kaggle/working/wav2vec2-base-960h"

# %%
TRAIN_AUDIO_DIR = "/kaggle/input/shl-dataset/dataset/audios_train"
TEST_AUDIO_DIR = "/kaggle/input/shl-dataset/dataset/audios_test"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_df = pd.read_csv('/kaggle/input/shl-dataset/dataset/train.csv')
test_df = pd.read_csv('/kaggle/input/shl-dataset/dataset/test.csv')

# %%
print("Train data sample:\n", train_df.head())
print("\nTest data sample:\n", test_df.head())
# Out:
# Train data sample:
#           filename  label
# 0  audio_1261.wav    1.0
# 1   audio_942.wav    1.5
# 2  audio_1110.wav    1.5
# 3  audio_1024.wav    1.5
# 4   audio_538.wav    2.0
#
# Test data sample:
#           filename
# 0   audio_706.wav
# 1   audio_800.wav
# 2    audio_68.wav
# 3  audio_1267.wav
# 4   audio_683.wav

# %%
try:
    processor = Wav2Vec2Processor.from_pretrained(MODEL_PATH)
    model = Wav2Vec2Model.from_pretrained(MODEL_PATH).to(device)
    print("\nModel loaded successfully from local files")
except Exception as e:
    print(f"\nError loading model: {str(e)}")
    raise
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at /kaggle/working/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model loaded successfully from local files

# %%
def process_audio(audio_path):
    try:
        waveform, sample_rate = torchaudio.load(audio_path)
        if sample_rate != 16000:
            resampler = torchaudio.transforms.Resample(sample_rate, 16000)
            waveform = resampler(waveform)
            
        speech = waveform.numpy().squeeze()
        inputs = processor(
            speech, 
            sampling_rate=16000, 
            return_tensors="pt", 
            padding=True
        ).to(device)
        
        with torch.no_grad():
            outputs = model(**inputs)
            
        return torch.mean(outputs.last_hidden_state, dim=1).squeeze().cpu().numpy()
    except Exception as e:
        print(f"Error processing {audio_path}: {str(e)}")
        return None

# %%
def extract_features(df, audio_dir):
    features = []
    valid_indices = []
    
    for idx, row in df.iterrows():
        audio_path = os.path.join(audio_dir, row['filename'])
        if not os.path.exists(audio_path):
            print(f"Missing file: {audio_path}")
            continue
            
        emb = process_audio(audio_path)
        if emb is not None and emb.shape == (768,):
            features.append(emb)
            valid_indices.append(idx)
        elif emb is not None:
            print(f"Unexpected shape {emb.shape} for {audio_path}")
    
    return np.array(features), df.iloc[valid_indices]['label'].values

# %%
print("Extracting training features...")
X_train, y_train = extract_features(train_df, TRAIN_AUDIO_DIR)
print(f"Retained {len(X_train)}/{len(train_df)} training samples")
# Out:
# Extracting training features...
# Unexpected shape (2, 768) for /kaggle/input/shl-dataset/dataset/audios_train/audio_1069.wav
# Unexpected shape (2, 768) for /kaggle/input/shl-dataset/dataset/audios_train/audio_142.wav
# Unexpected shape (2, 768) for /kaggle/input/shl-dataset/dataset/audios_train/audio_265.wav
# Unexpected shape (2, 768) for /kaggle/input/shl-dataset/dataset/audios_train/audio_978.wav
# Retained 440/444 training samples

# %%
def extract_features1(df, audio_dir, is_test=False):
    features = []
    valid_files = []
    
    for _, row in df.iterrows():
        audio_path = os.path.join(audio_dir, row['filename'])
        if not os.path.exists(audio_path):
            print(f"Missing file: {audio_path}")
            continue
            
        emb = process_audio(audio_path)
        if emb is not None and emb.shape == (768,):
            features.append(emb)
            valid_files.append(row['filename'])
        elif emb is not None:
            print(f"Unexpected shape {emb.shape} for {audio_path}")
    
    if not is_test:
        # For training data: return features and corresponding scores
        valid_df = df[df['filename'].isin(valid_files)]
        return np.array(features), valid_df['label'].values
    else:
        # For test data: return features and valid filenames
        return np.array(features), valid_files

# %%
print("\nExtracting test features...")
X_test, _ = extract_features1(test_df, TEST_AUDIO_DIR, is_test = True)
print(f"Retained {len(X_test)}/{len(test_df)} test samples")
# Out:
# Extracting test features...
# Unexpected shape (2, 768) for /kaggle/input/shl-dataset/dataset/audios_test/audio_159.wav
# Retained 194/195 test samples

# %%
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# %%
model_xgb = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=0.1,
    random_state=42
)

# %%
model_xgb.fit(
    X_train_split, y_train_split,
    eval_set=[(X_val_split, y_val_split)],
    early_stopping_rounds=20,
    verbose=10
)
# Out:
# [0]	validation_0-rmse:1.13688
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [10]	validation_0-rmse:0.98159
# [20]	validation_0-rmse:0.91270
# [30]	validation_0-rmse:0.86726
# [40]	validation_0-rmse:0.84400
# [50]	validation_0-rmse:0.83291
# [60]	validation_0-rmse:0.82604
# [70]	validation_0-rmse:0.82064
# [80]	validation_0-rmse:0.81635
# [90]	validation_0-rmse:0.81551
# [100]	validation_0-rmse:0.81200
# [110]	validation_0-rmse:0.81134
# [120]	validation_0-rmse:0.81002
# [130]	validation_0-rmse:0.80943
# [140]	validation_0-rmse:0.80884
# [150]	validation_0-rmse:0.80865
# [160]	validation_0-rmse:0.80850
# [170]	validation_0-rmse:0.80844
# [180]	validation_0-rmse:0.80831
# [190]	validation_0-rmse:0.80821
# [200]	validation_0-rmse:0.80834
# [210]	validation_0-rmse:0.80823
# [211]	validation_0-rmse:0.80820
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_val = model_xgb.predict(X_val_split)
print("\nValidation Metrics:")
print(f"Pearson Correlation: {pearsonr(y_val_split, y_pred_val)[0]:.3f}")
print(f"MAE: {mean_absolute_error(y_val_split, y_pred_val):.3f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_val_split, y_pred_val)):.3f}")
print(f"R²: {r2_score(y_val_split, y_pred_val):.3f}")
# Out:
# Validation Metrics:
# Pearson Correlation: 0.726
# MAE: 0.641
# RMSE: 0.808
# R²: 0.496

# %%
model_xgb_full = xgb.XGBRegressor(**model_xgb.get_params())
model_xgb_full.fit(X_train, y_train)
test_pred = model_xgb_full.predict(X_test)

# %%
test_pred
# Out:
# array([2.283736 , 3.077507 , 3.8344913, 2.8103576, 2.9851973, 3.1439705,
#        2.805294 , 3.0098987, 3.809254 , 2.5333908, 4.0089593, 2.8711233,
#        2.2458236, 2.7803092, 2.5848272, 3.8524003, 3.2458344, 2.5956657,
#        2.6441472, 2.6666782, 2.9051847, 2.3541162, 2.9529095, 2.6588418,
#        3.710727 , 3.7095172, 3.0199506, 2.4289646, 2.540497 , 2.2650635,
#        2.7567043, 3.5214188, 3.2258775, 2.6169264, 3.172329 , 2.6633925,
#        3.3045886, 2.6677783, 3.5227845, 2.8805273, 3.0557137, 3.1138039,
#        3.3101223, 2.7968438, 3.0654714, 2.9360442, 2.840825 , 3.3632696,
#        3.6854875, 4.07958  , 4.295764 , 3.7351675, 3.2002401, 2.3688438,
#        2.9930165, 3.0834892, 2.9392698, 3.913046 , 2.7459004, 2.9083862,
#        3.821058 , 4.2471094, 2.848333 , 4.030991 , 2.8120751, 2.4466026,
#        3.8947072, 2.614863 , 2.6794713, 3.3246212, 2.8015692, 3.6482399,
#        3.1244862, 3.7203999, 2.407901 , 2.9415426, 3.3674989, 3.182699 ,
#        2.658993 , 3.2915146, 3.020752 , 3.1854072, 3.7504106, 3.2199812,
#        3.0918486, 3.4235356, 3.5756557, 4.2304916, 3.1663334, 3.0863814,
#        3.8348842, 3.3631048, 2.998211 , 3.035707 , 2.7860653, 2.6959612,
#        4.593239 , 4.155469 , 3.4465108, 3.8626335, 4.351773 , 3.25604  ,
#        3.9453454, 3.7675433, 3.825732 , 4.5761456, 3.7728243, 4.581571 ,
#        4.6345286, 3.2643445, 3.8926532, 3.880862 , 3.555381 , 4.0233426,
#        4.1797433, 3.2214344, 4.958974 , 3.7519488, 3.824326 , 3.7376046,
#        4.5263505, 4.671096 , 3.091499 , 4.342903 , 3.4834466, 2.8434017,
#        2.737511 , 3.8584554, 2.987132 , 4.397148 , 4.5068927, 3.3911588,
#        2.9042077, 4.4006934, 3.9275343, 3.8952785, 3.2711384, 3.8047826,
#        3.58057  , 4.723766 , 4.333627 , 4.410084 , 3.5546658, 3.2028072,
#        4.3383493, 3.8001146, 4.400358 , 4.5193543, 3.3270147, 4.1248355,
#        3.841135 , 4.614176 , 4.313174 , 3.7859128, 4.2815266, 3.3208745,
#        3.9063313, 3.9541667, 2.5263267, 3.8555431, 4.754038 , 3.1733208,
#        4.0518312, 4.9012504, 4.093585 , 4.584688 , 4.9721746, 3.9999135,
#        4.402223 , 4.1620092, 4.098042 , 2.8848794, 4.440584 , 4.069305 ,
#        4.1740975, 4.373062 , 3.706338 , 3.9517827, 4.784522 , 4.091128 ,
#        4.526206 , 4.4277964, 4.1279683, 3.7056623, 4.080537 , 4.544919 ,
#        3.8697896, 4.4431577, 3.903169 , 3.7143412, 4.295243 , 4.231444 ,
#        3.9301577, 4.7508726], dtype=float32)

# %%
submission_df
# Out:
#            filename     label
# 0     audio_706.wav  2.283736
# 1     audio_800.wav  3.077507
# 2      audio_68.wav  3.834491
# 3    audio_1267.wav  2.810358
# 4     audio_683.wav  2.985197
# ..              ...       ...
# 190   audio_135.wav  4.295243
# 191   audio_512.wav  4.231444
# 192   audio_529.wav  3.930158
# 193   audio_762.wav  4.750873
# 194   audio_379.wav  0.000000
#
# [195 rows x 2 columns]

# %%
print(submission_df[submission_df['filename'] == 'audio_159.wav'])
# Out:
#           filename     label
# 111  audio_159.wav  3.880862

# %%
submission_df.to_csv("/kaggle/working/submission8.csv", index=False)

# %%
print(sf[sf['filename'] == 'audio_379.wav'])
# Out:
#           filename
# 194  audio_379.wav

# %%
def process_single_audio(audio_path):
    try:
        waveform, sample_rate = torchaudio.load(audio_path)
        
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        
        if sample_rate != 16000:
            resampler = torchaudio.transforms.Resample(sample_rate, 16000)
            waveform = resampler(waveform)
        
        speech = waveform.numpy().squeeze()
        inputs = processor(
            speech, 
            sampling_rate=16000, 
            return_tensors="pt", 
            padding=True
        ).to(device)
        
        with torch.no_grad():
            outputs = model(**inputs)
        
        embeddings = torch.mean(outputs.last_hidden_state, dim=1).squeeze().cpu().numpy()
        return embeddings
    
    except Exception as e:
        print(f"Error processing {audio_path}: {str(e)}")
        return None

# %%
suf = pd.read_csv('/kaggle/input/shl-dataset/dataset/test.csv')

# %%
print("Before processing:")
print(suf[suf['filename'] == 'audio_379.wav'])
# Out:
# Before processing:
#           filename
# 194  audio_379.wav

# %%
audio_path = os.path.join(TEST_AUDIO_DIR, 'audio_379.wav')

# %%
if os.path.exists(audio_path):
    # Get embeddings
    embeddings = process_single_audio(audio_path)
    
    if embeddings is not None and embeddings.shape == (768,):
        # Predict score
        new_score = model_xgb_full.predict([embeddings])[0]
        
        # Update submission
        suf.loc[
            suf['filename'] == 'audio_379.wav',
            'label'
        ] = new_score
        
        print("\nAfter processing:")
        print(suf[suf['filename'] == 'audio_379.wav'])
    else:
        print("\nFailed to process audio_379.wav - using existing score")
else:
    print(f"\nFile not found: {audio_path}")
# Out:
# After processing:
#           filename     label
# 194  audio_379.wav  4.750873

# %%
suf
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#            filename     label
# 0     audio_706.wav       NaN
# 1     audio_800.wav       NaN
# 2      audio_68.wav       NaN
# 3    audio_1267.wav       NaN
# 4     audio_683.wav       NaN
# ..              ...       ...
# 190   audio_135.wav       NaN
# 191   audio_512.wav       NaN
# 192   audio_529.wav       NaN
# 193   audio_762.wav       NaN
# 194   audio_379.wav  4.750873
#
# [195 rows x 2 columns]

# %%
submission_df = submission_df.merge(
    pd.read_csv('/kaggle/input/shl-dataset/dataset/sample_submission.csv')[['filename']],
    on='filename',
    how='right'
).fillna(0)

# %%
submission_df.loc[submission_df['filename'] == 'audio_379.wav', 'label'] = suf['label'][len(suf) - 1]

# %%
submission_df
# Out:
#            filename     label
# 0     audio_706.wav  2.283736
# 1     audio_800.wav  3.077507
# 2      audio_68.wav  3.834491
# 3    audio_1267.wav  2.810358
# 4     audio_683.wav  2.985197
# ..              ...       ...
# 190   audio_135.wav  4.295243
# 191   audio_512.wav  4.231444
# 192   audio_529.wav  3.930158
# 193   audio_762.wav  4.750873
# 194   audio_379.wav  4.750873
#
# [195 rows x 2 columns]

# %%
print(submission_df[submission_df['filename'] == 'audio_159.wav'])
# Out:
#           filename     label
# 111  audio_159.wav  3.880862

# %%
submission_df['label'][111]
# Out:
# 3.880862
